# %%
from rattlesnake.headless import *
from rattlesnake.examples import *
# %gui qt

# %%
rattlesnake = RattlesnakeController()
app, rattlesnake_ui = build_rattlesnake_app(rattlesnake, set_font_size=False)

# %%
rattlesnake_ui.show()
